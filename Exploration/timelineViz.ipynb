# %%
import pickle
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pgf import FigureCanvasPgf
import seaborn as sns

matplotlib.backend_bases.register_backend('pdf', FigureCanvasPgf)
matplotlib.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
})

# %%
with open('../data/raw/timeline_dataset.pkl', 'rb') as f:
    df = pickle.load(f)
    print(df.shape)
# Out:
# (112342, 472)

# %%
# number of matchids in dataset
matchIds = df.index.get_level_values('matchId').unique()
print(len(matchIds))
# Out:
# 3972

# %%
df.head(10)
# Out:
#                        timestamp  winning_team  participant1_participantId  \
# matchId       frameId
# KR_6748606904 604108           0             1                           1
#               604109       60013             1                           1
#               604110      120021             1                           1
#               604111      180028             1                           1
#               604112      240041             1                           1
#               604113      300056             1                           1
#               604114      360086             1                           1
#               604115      420118             1                           1
#               604116      480142             1                           1
#               604117      540154             1                           1
#
#                        participant1_abilityHaste  participant1_abilityPower  \
# matchId       frameId
# KR_6748606904 604108                           0                          0
#               604109                           0                          0
#               604110                           0                          0
#               604111                           0                          0
#               604112                           0                          0
#               604113                           0                          0
#               604114                           0                          0
#               604115                           0                          0
#               604116                           0                          0
#               604117                           0                          0
#
#                        participant1_armor  participant1_armorPen  \
# matchId       frameId
# KR_6748606904 604108                   35                      0
#               604109                   41                      0
#               604110                   41                      0
#               604111                   44                      0
#               604112                   52                      0
#               604113                   56                      0
#               604114                   60                      0
#               604115                   60                      0
#               604116                   65                      0
#               604117                   69                      0
#
#                        participant1_armorPenPercent  \
# matchId       frameId
# KR_6748606904 604108                              0
#               604109                              0
#               604110                              0
#               604111                              0
#               604112                              0
#               604113                              0
#               604114                              0
#               604115                              0
#               604116                              0
#               604117                              0
#
#                        participant1_attackDamage  participant1_attackSpeed  \
# matchId       frameId
# KR_6748606904 604108                          25                       100
#               604109                          73                       100
#               604110                          73                       100
#               604111                          77                       101
#               604112                          84                       105
#               604113                          88                       107
#               604114                         118                       109
#               604115                         118                       109
#               604116                         122                       112
#               604117                         127                       114
#
#                        ...  participant10_trueDamageTaken  \
# matchId       frameId  ...
# KR_6748606904 604108   ...                              0
#               604109   ...                              0
#               604110   ...                              0
#               604111   ...                              3
#               604112   ...                             97
#               604113   ...                             97
#               604114   ...                            187
#               604115   ...                            187
#               604116   ...                            187
#               604117   ...                            187
#
#                        participant10_goldPerSecond  \
# matchId       frameId
# KR_6748606904 604108                             0
#               604109                            20
#               604110                            20
#               604111                            20
#               604112                            20
#               604113                            20
#               604114                            20
#               604115                            20
#               604116                            20
#               604117                            20
#
#                        participant10_jungleMinionsKilled  participant10_level  \
# matchId       frameId
# KR_6748606904 604108                                   0                    1
#               604109                                   0                    1
#               604110                                   0                    1
#               604111                                   0                    1
#               604112                                   0                    2
#               604113                                   0                    3
#               604114                                   0                    3
#               604115                                   0                    4
#               604116                                   0                    4
#               604117                                   0                    5
#
#                        participant10_minionsKilled  participant10_position_x  \
# matchId       frameId
# KR_6748606904 604108                             0                     14281
#               604109                             0                     12542
#               604110                             0                     12133
#               604111                             2                     13438
#               604112                             2                     14003
#               604113                             5                     12152
#               604114                             7                     13052
#               604115                            10                     12190
#               604116                            13                     12270
#               604117                            16                     13047
#
#                        participant10_position_y  \
# matchId       frameId
# KR_6748606904 604108                      14199
#               604109                       4911
#               604110                       2749
#               604111                       3685
#               604112                      14105
#               604113                       1959
#               604114                       5092
#               604115                       9314
#               604116                       1421
#               604117                       2179
#
#                        participant10_timeEnemySpentControlled  \
# matchId       frameId
# KR_6748606904 604108                                        0
#               604109                                        0
#               604110                                    19078
#               604111                                    29518
#               604112                                    61118
#               604113                                    69093
#               604114                                    86434
#               604115                                   117435
#               604116                                   117435
#               604117                                   136481
#
#                        participant10_totalGold  participant10_xp
# matchId       frameId
# KR_6748606904 604108                       500                 0
#               604109                       500                 0
#               604110                       523                 0
#               604111                       868               221
#               604112                      1452               438
#               604113                      1772               664
#               604114                      2216              1089
#               604115                      2482              1285
#               604116                      2702              1530
#               604117                      3027              1933
#
# [10 rows x 472 columns]

# %%
p1_armor = df.loc['KR_6748606904']['participant1_armor']
p1_health = df.loc['KR_6748606904']['participant1_health']
p1_healtMax = df.loc['KR_6748606904']['participant1_healthMax']
p1_movespeed = df.loc['KR_6748606904']['participant1_movementSpeed']
p1_currentGold = df.loc['KR_6748606904']['participant1_currentGold']
p1_physicalDamage = df.loc['KR_6748606904']['participant1_physicalDamageDone']
p1_totalGold = df.loc['KR_6748606904']['participant1_totalGold']
p1_totalDamageToChampions = df.loc['KR_6748606904']['participant1_totalDamageDoneToChampions']
timestamps = df.loc['KR_6748606904']['timestamp']
timestamps = timestamps / 60000

# %%
ax = sns.lineplot(x=timestamps, y=p1_armor.values)
ax.set(xlabel='Time (minutes)', ylabel='Armor')
ax.set_title('Player 1 Armor')
plt.savefig('../thesis/images/participant1_armor.pgf')

# %%
ax = sns.lineplot(x=timestamps, y=p1_health.values)
ax.set(xlabel='Time (minutes)', ylabel='Health')
ax.set_title('Player 1 Health')
plt.savefig('../thesis/images/participant1_health.pgf')

# %%
ax = sns.lineplot(x=timestamps, y=p1_healtMax.values)
ax.set(xlabel='Time (minutes)', ylabel='Max Health')
ax.set_title('Player 1 Max Health')
plt.savefig('../thesis/images/participant1_maxHealth.pgf')

# %%
ax = sns.lineplot(x=timestamps, y=p1_movespeed.values)
ax.set(xlabel='Time (minutes)', ylabel='Movement Speed')
ax.set_title('Player 1 Movement Speed')
plt.savefig('../thesis/images/participant1_movementSpeed.pgf')

# %%
ax = sns.lineplot(x=timestamps, y=p1_currentGold.values)
ax.set(xlabel='Time (minutes)', ylabel='Current Gold')
ax.set_title('Player 1 Current Gold')
plt.savefig('../thesis/images/participant1_currentGold.pgf')

# %%
ax = sns.lineplot(x=timestamps, y=p1_physicalDamage.values)
ax.set(xlabel='Time (minutes)', ylabel='Physical Damage Done')
ax.set_title('Player 1 Physical Damage Done')
plt.savefig('../thesis/images/participant1_physicalDamage.pgf')

# %%
ax = sns.lineplot(x=timestamps, y=p1_totalGold.values)
ax.set(xlabel='Time (minutes)', ylabel='Total Gold')
ax.set_title('Player 1 Total Gold')
plt.savefig('../thesis/images/participant1_totalGold.pgf')

# %%
ax = sns.lineplot(x=timestamps, y=p1_totalDamageToChampions.values)
ax.set(xlabel='Time (minutes)', ylabel='Total Damage Done To Champions')
ax.set_title('Player 1 Total Damage Done To Champions')
plt.savefig('../thesis/images/participant1_totalDamageToChampions.pgf')

# %%
participants_totalGold = ['participant1_totalGold', 'participant2_totalGold', 'participant3_totalGold',
                          'participant4_totalGold',
                          'participant5_totalGold', 'participant6_totalGold', 'participant7_totalGold',
                          'participant8_totalGold',
                          'participant9_totalGold', 'participant10_totalGold']
participants_Ids = ['participant1_participantId', 'participant2_participantId', 'participant3_participantId',
                    'participant4_participantId',
                    'participant5_participantId', 'participant6_participantId', 'participant7_participantId',
                    'participant8_participantId',
                    'participant9_participantId', 'participant10_participantId']
df_totalGold = df.loc['KR_6748606904'][participants_totalGold]
df_participantIds = df.loc['KR_6748606904'][participants_Ids]
combined_df = pd.concat([timestamps, df_totalGold, df_participantIds], axis=1)
df_totalGold
# Out:
#          participant1_totalGold  participant2_totalGold  \
# frameId
# 604108                      500                     500
# 604109                      500                     500
# 604110                      535                     596
# 604111                      769                    1328
# 604112                     1067                    2513
# 604113                     1378                    2936
# 604114                     1721                    3624
# 604115                     2157                    3976
# 604116                     2497                    4704
# 604117                     2812                    5138
# 604118                     3239                    5475
# 604119                     3619                    5952
# 604120                     4008                    6631
# 604121                     5256                    6994
# 604122                     6218                    7432
# 604123                     6640                    7739
# 604124                     7140                    8441
# 604125                     7633                    9987
# 604126                     8992                   10468
# 604127                     9740                   10911
# 604128                    10057                   11253
# 604129                    11032                   11995
# 604130                    11424                   12430
# 604131                    11664                   12638
# 604132                    12044                   12761
# 604133                    12594                   13436
# 604134                    12695                   13892
#
#          participant3_totalGold  participant4_totalGold  \
# frameId
# 604108                      500                     500
# 604109                      500                     500
# 604110                      591                     542
# 604111                      969                    1178
# 604112                     1582                    1747
# 604113                     1879                    1954
# 604114                     2407                    2352
# 604115                     3440                    3199
# 604116                     3969                    3524
# 604117                     4663                    3900
# 604118                     4953                    4657
# 604119                     5283                    5070
# 604120                     6226                    5730
# 604121                     6628                    6327
# 604122                     7264                    7570
# 604123                     7503                    8022
# 604124                     8823                    8611
# 604125                     9161                    9510
# 604126                     9820                   10656
# 604127                    10097                   11132
# 604128                    10220                   11582
# 604129                    10858                   12073
# 604130                    11177                   12485
# 604131                    11350                   13027
# 604132                    11514                   13225
# 604133                    11903                   13663
# 604134                    12529                   14567
#
#          participant5_totalGold  participant6_totalGold  \
# frameId
# 604108                      500                     500
# 604109                      500                     500
# 604110                      523                     584
# 604111                      863                     935
# 604112                     1266                    1173
# 604113                     1442                    1551
# 604114                     1664                    1935
# 604115                     1961                    2235
# 604116                     2164                    2599
# 604117                     2457                    2842
# 604118                     2783                    3233
# 604119                     2967                    3612
# 604120                     3232                    4289
# 604121                     3918                    4425
# 604122                     4458                    4597
# 604123                     4678                    5327
# 604124                     5202                    5965
# 604125                     5747                    6232
# 604126                     6492                    6376
# 604127                     6682                    6561
# 604128                     6822                    7262
# 604129                     7331                    7385
# 604130                     7567                    7772
# 604131                     7757                    8570
# 604132                     7897                    9061
# 604133                     8540                    9299
# 604134                     8649                    9350
#
#          participant7_totalGold  participant8_totalGold  \
# frameId
# 604108                      500                     500
# 604109                      500                     500
# 604110                      611                     605
# 604111                      938                     888
# 604112                     1131                    1294
# 604113                     1647                    1933
# 604114                     1844                    2189
# 604115                     2141                    2545
# 604116                     2494                    2898
# 604117                     2725                    3170
# 604118                     2948                    3425
# 604119                     3175                    3944
# 604120                     3553                    4066
# 604121                     4311                    4417
# 604122                     4817                    4752
# 604123                     5334                    5213
# 604124                     5672                    5993
# 604125                     5944                    6715
# 604126                     6067                    7079
# 604127                     6278                    7431
# 604128                     6400                    7595
# 604129                     6523                    7879
# 604130                     6770                    8073
# 604131                     7865                    8384
# 604132                     8273                    8877
# 604133                     8600                    9381
# 604134                     8651                    9732
#
#          participant9_totalGold  participant10_totalGold
# frameId
# 604108                      500                      500
# 604109                      500                      500
# 604110                      521                      523
# 604111                     1186                      868
# 604112                     1398                     1452
# 604113                     2718                     1772
# 604114                     3074                     2216
# 604115                     3584                     2482
# 604116                     3933                     2702
# 604117                     4412                     3027
# 604118                     4745                     3182
# 604119                     5122                     3418
# 604120                     5753                     4450
# 604121                     5975                     4665
# 604122                     6194                     4848
# 604123                     7115                     5193
# 604124                     7540                     5573
# 604125                     7775                     5784
# 604126                     8134                     5966
# 604127                     8996                     6107
# 604128                     9458                     6262
# 604129                    10075                     6402
# 604130                    10376                     6578
# 604131                    12794                     6808
# 604132                    13451                     6984
# 604133                    14346                     7255
# 604134                    14565                     7313

# %%
df_gold = pd.concat([timestamps, df_totalGold], axis=1)
df_gold = pd.melt(df_gold, id_vars=['timestamp'], value_vars=participants_totalGold)
df_gold['variable'] = df_gold['variable'].str.replace('_',
                                                      '')  # latex seems to have problems with underscores in labels
df_gold
# Out:
#      timestamp                variable  value
# 0     0.000000   participant1totalGold    500
# 1     1.000217   participant1totalGold    500
# 2     2.000350   participant1totalGold    535
# 3     3.000467   participant1totalGold    769
# 4     4.000683   participant1totalGold   1067
# ..         ...                     ...    ...
# 265  22.006217  participant10totalGold   6578
# 266  23.006300  participant10totalGold   6808
# 267  24.006483  participant10totalGold   6984
# 268  25.006517  participant10totalGold   7255
# 269  25.422283  participant10totalGold   7313
#
# [270 rows x 3 columns]

# %%
sns.color_palette("blend:royalblue,navy", 5)
# Out:
# [(0.2549019607843137, 0.4117647058823529, 0.8823529411764706),
#  (0.1909265667051134, 0.30841983852364474, 0.786881968473664),
#  (0.1269511726259131, 0.20507497116493656, 0.6914109957708574),
#  (0.0629757785467128, 0.10173010380622838, 0.5959400230680507),
#  (0.0, 0.0, 0.5019607843137255)]

# %%
sns.color_palette("blend:lightcoral,firebrick", 5)
# Out:
# [(0.9411764705882353, 0.5019607843137255, 0.5019607843137255),
#  (0.880153787004998, 0.4094425221068819, 0.4094425221068819),
#  (0.8191311034217609, 0.3169242599000384, 0.3169242599000384),
#  (0.7581084198385236, 0.22440599769319491, 0.22440599769319491),
#  (0.6980392156862745, 0.13333333333333333, 0.13333333333333333)]

# %%
blue_palette = sns.color_palette("blend:cornflowerblue,navy", 5)  # Adjust the number if needed
red_palette = sns.color_palette("blend:lightcoral,firebrick", 5)  # Adjust the number if needed

# Combine the palettes
combined_palette = blue_palette + red_palette
ax = sns.lineplot(data=df_gold, x='timestamp', y='value', hue='variable', palette=combined_palette)
ax.set(xlabel='Time (minutes)', ylabel='Gold')
ax.set_title('Total Gold of each player per minute')
handles, labels = ax.get_legend_handles_labels()
custom_labels = ['Player 1', 'Player 2', 'Player 3', 'Player 4', 'Player 5', 'Player 6', 'Player 7', 'Player 8',
                 'Player 9', 'Player 10']
ax.legend(handles=handles, labels=custom_labels, loc='upper left')
plt.savefig('../thesis/images/totalGold.pgf')

# %%
# TODO: calculate team Id from winning team for each participant, use it in dataset cleaning and visualization
